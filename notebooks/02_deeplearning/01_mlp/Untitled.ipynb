# %%
import tensorflow as tf

cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(32, 32, 3),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 2023-10-04 10:21:55.437754: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 782/782 [==============================] - 107s 111ms/step - loss: 4.7327 - accuracy: 0.0680
# Epoch 2/5
# 782/782 [==============================] - 75s 96ms/step - loss: 3.8960 - accuracy: 0.1454
# Epoch 3/5
# 782/782 [==============================] - 75s 96ms/step - loss: 4.1748 - accuracy: 0.1452
# Epoch 4/5
# 782/782 [==============================] - 75s 96ms/step - loss: 4.1763 - accuracy: 0.1073
# Epoch 5/5
# 782/782 [==============================] - 75s 96ms/step - loss: 3.6741 - accuracy: 0.1644
